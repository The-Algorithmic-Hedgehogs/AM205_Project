# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import math
import scipy.optimize as optimize
from scipy import integrate

# %%
#Define parameters from paper

alpha_ptc = 0.024
gamma_p = 0.006
gamma_c = 0.1539
K_h = 2.2771
k_off = 0.3018
k_on = K_h * k_off
K_p = 0.5660
n_p = 0.9
alpha_R = 0.3908
gamma_R = 0.002
K_R = 8.5184
n_R = 1.5735
alpha_GBS = 5.6881e-3
alpha_GBS0 = 9.8715e-5
D_diff = 58.3931
alpha_HH = 0.5431
gamma_H = 8.1346e-4
beta = 36
m = 1.8657

# %%
def create_d_matrix(n):
    h = 1/(n-1)
    D = -2*np.identity(n)
    
    for i in range(n-1):
        D[i+1, i] = 1
        D[i, i+1] = 1
        
    D[n-1] = 0
    D[0,1] = 2
    
    return D

# %%
def update_H(H, P, C, t):
    n = len(H)
    h = 1/(n-1)
    alpha = (D_diff*t)/(h**2)
    M = H - (gamma_H*H) - (k_on*H*P) + (k_off*C)
    M[0] += (alpha_HH/D_diff)*2*h*alpha
    Differentiation_Matrix = create_d_matrix(n)
    A = np.identity(n) - alpha*Differentiation_Matrix
    future_H = np.linalg.solve(A, M)
    
    
    for i in range(n):
        if future_H[i] < 0:
            future_H[i] = 0
    
    return future_H

def phi_R(R):
    n = len(R)
    phi = np.zeros(n)
    for i in range(n):
        phi[i] = (K_R**n_R)/((K_R**n_R)+(R[i]**n_R))
    return phi

def update_P(H, P, R, C, t):
    n = len(H)
    delta = ((alpha_ptc)*np.ones(n)) + ((alpha_ptc)*beta*phi_R(R)) - (gamma_p*P) - (k_on*H*P) + (k_off*C)
    future_P = P + delta*t
    
    for i in range(n):
        if future_P[i] < 0:
            future_P[i] = 0
    return future_P
    
def update_C(H, P, C, t):
    n = len(H)
    delta = (k_on*H*P) - (k_off*C) - (gamma_c*C)
    future_C = C + delta*t
    
    for i in range(n):
        if future_C[i] < 0:
            future_C[i] = 0
            
    return future_C

def update_R(P, R, t):
    n = len(P)
    delta = np.zeros(n)
    for i in range(n):
        delta[i] = alpha_R*((P[i]**n_p)/((K_p**n_p)+(P[i]**n_p))) - (gamma_R*R[i])
    future_R = R + delta*t
    
    for i in range(n):
        if future_R[i] < 0:
            future_R[i] = 0
            
    return future_R

def update_S(R, S, t):
    n = len(R)
    delta = ((alpha_GBS0*np.ones(n)) + (alpha_GBS*phi_R(R))) #*1000
    future_S = S + delta*t
    
    for i in range(n):
        if future_S[i] < 0:
            future_S[i] = 0
    return future_S

# %%
def integrate_solution(final_time, time_step, n):
    H = np.zeros(n)
    C = np.zeros(n)
    S = np.zeros(n)
    P = 5.25*np.ones(n)
    R = 172.23*np.ones(n) #188.735*np.ones(n)
    time = 0
    Hs = H[0]
    
    hrs = int(np.floor( final_time / 60)); #number of hours we will simulate over
    #make arrays to hold the values of each protein at each grid point at each hour
    H_vals = np.zeros((hrs,n));
    H_vals[0] = H; #initialize at t=0
    C_vals = np.zeros((hrs,n));
    C_vals[0] = C; #initialize at t=0
    S_vals = np.zeros((hrs,n));
    S_vals[0] = S; #initialize at t=0
    P_vals = np.zeros((hrs,n));
    P_vals[0] = P; #initialize at t=0
    R_vals = np.zeros((hrs,n));
    R_vals[0] = R; #initialize at t=0
    
    steps_each_hr = 60 / time_step + 1;
    steps = 0
    
    while time<final_time:
#         print(time)
        H = update_H(H, P, C, time_step)
        P = update_P(H, P, R, C, time_step)
        C = update_C(H, P, C, time_step)
        R = update_R(P, R, time_step)
        S = update_S(R, S, time_step)
        
        time += time_step #increment total time
        steps +=1 ;
        if steps == steps_each_hr : #we've reached an hour
            #store protein concentrations at each grid point for this hour
            index = int(time / 60);
            print("Index to insert at:", index);
            H_vals[index] = H;
            P_vals[index] = P;
            R_vals[index] = R;
            C_vals[index] = C;
            S_vals[index] = S;
            steps = 0; #reinitialize steps
        
    return H_vals, P_vals, C_vals, R_vals, S_vals;

# %%
from time import clock

c = clock();
hrs_to_sim = 30
H, P, C, R, S = integrate_solution(hrs_to_sim*60, 0.01, 500)
stop = clock();

print("Time: {0} min".format( (stop-c)/60 ) );
# Out:
# Index to insert at: 1
# Index to insert at: 2
# Index to insert at: 3
# Index to insert at: 4
# Index to insert at: 5
# Index to insert at: 6
# Index to insert at: 7
# Index to insert at: 8
# Index to insert at: 9
# Index to insert at: 10
# Index to insert at: 11
# Index to insert at: 12
# Index to insert at: 13
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-2e9adb5e359e> in <module>()
#       2
#       3 c = clock();
# ----> 4 H, P, C, R, S = integrate_solution(1800, 0.01, 500)
#       5 stop = clock();
#       6
#
# <ipython-input-43-c1dd7dffd16d> in integrate_solution(final_time, time_step, n)
#      26     while time<final_time:
#      27 #         print(time)
# ---> 28         H = update_H(H, P, C, time_step)
#      29         P = update_P(H, P, R, C, time_step)
#      30         C = update_C(H, P, C, time_step)
#
# <ipython-input-4-bcfa0f89126f> in update_H(H, P, C, t)
#       7     Differentiation_Matrix = create_d_matrix(n)
#       8     A = np.identity(n) - alpha*Differentiation_Matrix
# ----> 9     future_H = np.linalg.solve(A, M)
#      10
#      11
#
# ~/anaconda3/lib/python3.6/site-packages/numpy/linalg/linalg.py in solve(a, b)
#     388     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     389     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 390     r = gufunc(a, b, signature=signature, extobj=extobj)
#     391
#     392     return wrap(r.astype(result_t, copy=False))
#
# KeyboardInterrupt:

# %%
S[29]
# Out:
# array([0.27022099, 0.27021427, 0.27020755, 0.27020083, 0.27019412,
#        0.27018741, 0.2701807 , 0.270174  , 0.2701673 , 0.27016061,
#        0.27015392, 0.27014723, 0.27014054, 0.27013386, 0.27012719,
#        0.27012052, 0.27011385, 0.27010718, 0.27010052, 0.27009387,
#        0.27008721, 0.27008056, 0.27007392, 0.27006727, 0.27006063,
#        0.270054  , 0.27004737, 0.27004074, 0.27003411, 0.27002749,
#        0.27002088, 0.27001426, 0.27000765, 0.27000105, 0.26999444,
#        0.26998785, 0.26998125, 0.26997466, 0.26996807, 0.26996149,
#        0.2699549 , 0.26994833, 0.26994175, 0.26993518, 0.26992862,
#        0.26992205, 0.26991549, 0.26990894, 0.26990238, 0.26989583,
#        0.26988929, 0.26988275, 0.26987621, 0.26986967, 0.26986314,
#        0.26985661, 0.26985009, 0.26984356, 0.26983705, 0.26983053,
#        0.26982402, 0.26981751, 0.26981101, 0.26980451, 0.26979801,
#        0.26979152, 0.26978503, 0.26977854, 0.26977205, 0.26976557,
#        0.2697591 , 0.26975262, 0.26974615, 0.26973968, 0.26973322,
#        0.26972676, 0.2697203 , 0.26971385, 0.2697074 , 0.26970095,
#        0.26969451, 0.26968807, 0.26968163, 0.2696752 , 0.26966876,
#        0.26966234, 0.26965591, 0.26964949, 0.26964307, 0.26963666,
#        0.26963025, 0.26962384, 0.26961744, 0.26961103, 0.26960464,
#        0.26959824, 0.26959185, 0.26958546, 0.26957907, 0.26957269,
#        0.26956631, 0.26955993, 0.26955356, 0.26954719, 0.26954082,
#        0.26953446, 0.2695281 , 0.26952174, 0.26951539, 0.26950904,
#        0.26950269, 0.26949634, 0.26949   , 0.26948366, 0.26947733,
#        0.26947099, 0.26946466, 0.26945834, 0.26945201, 0.26944569,
#        0.26943938, 0.26943306, 0.26942675, 0.26942044, 0.26941414,
#        0.26940783, 0.26940153, 0.26939524, 0.26938894, 0.26938265,
#        0.26937637, 0.26937008, 0.2693638 , 0.26935752, 0.26935124,
#        0.26934497, 0.2693387 , 0.26933243, 0.26932617, 0.26931991,
#        0.26931365, 0.26930739, 0.26930114, 0.26929489, 0.26928864,
#        0.2692824 , 0.26927616, 0.26926992, 0.26926368, 0.26925745,
#        0.26925122, 0.26924499, 0.26923877, 0.26923255, 0.26922633,
#        0.26922011, 0.2692139 , 0.26920769, 0.26920148, 0.26919527,
#        0.26918907, 0.26918287, 0.26917668, 0.26917048, 0.26916429,
#        0.2691581 , 0.26915192, 0.26914573, 0.26913955, 0.26913337,
#        0.2691272 , 0.26912103, 0.26911486, 0.26910869, 0.26910252,
#        0.26909636, 0.2690902 , 0.26908405, 0.26907789, 0.26907174,
#        0.26906559, 0.26905944, 0.2690533 , 0.26904716, 0.26904102,
#        0.26903489, 0.26902875, 0.26902262, 0.26901649, 0.26901037,
#        0.26900424, 0.26899812, 0.268992  , 0.26898589, 0.26897978,
#        0.26897366, 0.26896756, 0.26896145, 0.26895535, 0.26894925,
#        0.26894315, 0.26893705, 0.26893096, 0.26892487, 0.26891878,
#        0.26891269, 0.26890661, 0.26890053, 0.26889445, 0.26888837,
#        0.2688823 , 0.26887622, 0.26887016, 0.26886409, 0.26885802,
#        0.26885196, 0.2688459 , 0.26883984, 0.26883379, 0.26882773,
#        0.26882168, 0.26881564, 0.26880959, 0.26880355, 0.2687975 ,
#        0.26879146, 0.26878543, 0.26877939, 0.26877336, 0.26876733,
#        0.2687613 , 0.26875528, 0.26874925, 0.26874323, 0.26873721,
#        0.26873119, 0.26872518, 0.26871917, 0.26871316, 0.26870715,
#        0.26870114, 0.26869514, 0.26868914, 0.26868314, 0.26867714,
#        0.26867114, 0.26866515, 0.26865916, 0.26865317, 0.26864718,
#        0.2686412 , 0.26863521, 0.26862923, 0.26862325, 0.26861728,
#        0.2686113 , 0.26860533, 0.26859936, 0.26859339, 0.26858743,
#        0.26858146, 0.2685755 , 0.26856954, 0.26856358, 0.26855762,
#        0.26855167, 0.26854572, 0.26853976, 0.26853382, 0.26852787,
#        0.26852192, 0.26851598, 0.26851004, 0.2685041 , 0.26849816,
#        0.26849223, 0.2684863 , 0.26848036, 0.26847444, 0.26846851,
#        0.26846258, 0.26845666, 0.26845074, 0.26844482, 0.2684389 ,
#        0.26843298, 0.26842707, 0.26842115, 0.26841524, 0.26840933,
#        0.26840342, 0.26839752, 0.26839161, 0.26838571, 0.26837981,
#        0.26837391, 0.26836801, 0.26836212, 0.26835623, 0.26835033,
#        0.26834444, 0.26833855, 0.26833267, 0.26832678, 0.2683209 ,
#        0.26831502, 0.26830914, 0.26830326, 0.26829738, 0.26829151,
#        0.26828563, 0.26827976, 0.26827389, 0.26826802, 0.26826215,
#        0.26825629, 0.26825042, 0.26824456, 0.2682387 , 0.26823284,
#        0.26822698, 0.26822113, 0.26821527, 0.26820942, 0.26820357,
#        0.26819772, 0.26819187, 0.26818602, 0.26818018, 0.26817433,
#        0.26816849, 0.26816265, 0.26815681, 0.26815097, 0.26814513,
#        0.2681393 , 0.26813346, 0.26812763, 0.2681218 , 0.26811597,
#        0.26811014, 0.26810431, 0.26809849, 0.26809266, 0.26808684,
#        0.26808102, 0.2680752 , 0.26806938, 0.26806356, 0.26805774,
#        0.26805193, 0.26804611, 0.2680403 , 0.26803449, 0.26802868,
#        0.26802287, 0.26801706, 0.26801126, 0.26800545, 0.26799965,
#        0.26799385, 0.26798805, 0.26798225, 0.26797645, 0.26797065,
#        0.26796485, 0.26795906, 0.26795326, 0.26794747, 0.26794168,
#        0.26793589, 0.2679301 , 0.26792431, 0.26791852, 0.26791274,
#        0.26790695, 0.26790117, 0.26789538, 0.2678896 , 0.26788382,
#        0.26787804, 0.26787226, 0.26786649, 0.26786071, 0.26785493,
#        0.26784916, 0.26784339, 0.26783761, 0.26783184, 0.26782607,
#        0.2678203 , 0.26781453, 0.26780877, 0.267803  , 0.26779723,
#        0.26779147, 0.26778571, 0.26777994, 0.26777418, 0.26776842,
#        0.26776266, 0.2677569 , 0.26775114, 0.26774538, 0.26773963,
#        0.26773387, 0.26772812, 0.26772236, 0.26771661, 0.26771086,
#        0.2677051 , 0.26769935, 0.2676936 , 0.26768785, 0.26768211,
#        0.26767636, 0.26767061, 0.26766486, 0.26765912, 0.26765337,
#        0.26764763, 0.26764189, 0.26763614, 0.2676304 , 0.26762466,
#        0.26761892, 0.26761318, 0.26760744, 0.2676017 , 0.26759596,
#        0.26759023, 0.26758449, 0.26757875, 0.26757302, 0.26756728,
#        0.26756155, 0.26755582, 0.26755008, 0.26754435, 0.26753862,
#        0.26753289, 0.26752716, 0.26752143, 0.2675157 , 0.26750997,
#        0.26750424, 0.26749851, 0.26749278, 0.26748705, 0.26748133,
#        0.2674756 , 0.26746988, 0.26746415, 0.26745842, 0.2674527 ,
#        0.26744698, 0.26744125, 0.26743553, 0.26742981, 0.26742408,
#        0.26741836, 0.26741264, 0.26740692, 0.2674012 , 0.26739548,
#        0.26738976, 0.26738403, 0.26737831, 0.2673726 , 0.26736688,
#        0.26736116, 0.26735544, 0.26734972, 0.267344  , 0.26733828,
#        0.26733257, 0.26732685, 0.26732113, 0.26731541, 0.2673097 ,
#        0.26730398, 0.26729826, 0.26729255, 0.26728683, 0.26728112,
#        0.2672754 , 0.26726969, 0.26726397, 0.26725825, 0.26725254,
#        0.26724682, 0.26724111, 0.26723539, 0.26722968, 0.26722396,
#        0.26721825, 0.26721253, 0.26720682, 0.26720111, 0.26719539])

# %%
S_normed = S[29] / np.max(S[29])

# %%
fig, ax = plt.subplots(figsize=(15, 7))
ax.grid(True, lw=1.76, ls='--', alpha = 0.15)
plt.plot(S_normed, '', color = 'b')
#plt.plot(R, '', color = 'r', ms =10)
plt.show()
