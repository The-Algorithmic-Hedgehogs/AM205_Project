# %% [markdown]
# ## Made this notebook to do a full run with 100hrs at 0.1 time step.
#
# Collecting P, C, R, S, F2, F3, A every half-hour. Collecting S every 0.5min.

# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import math
import scipy.optimize as optimize
from scipy import integrate

# %%
#Define parameters from paper
alpha_ptc = 0.024
gamma_p = 0.006
gamma_c = 0.1067
K_h = 1.8124
k_off = 0.9157
k_on = K_h * k_off
K_p = 0.01
n_p = 1.3007
alpha_f = 0.7610
gamma_f = 0.002
alpha_a = 1.9996
alpha_R2 = 0.00326
alpha_R3 = 0.0315
gamma_a = 0.02
gamma_R = 0.002
K_gli = 0.1501
alpha_GBS = 0.0022
alpha_GBS0 = 1.384e-4
D_diff = 52.3942
alpha_HH = 0.4898
gamma_H = 7.644e-6
beta = 16
m = 2.5595
beta_fl = 2.3797
t_dr = 30

# %%
def create_d_matrix(n):
    h = 1/(n-1)
    D = -2*np.identity(n) 
    for i in range(n-1):
        D[i+1, i] = 1
        D[i, i+1] = 1       
    D[n-1] = 0
    D[0,1] = 2    
    return D

# %%
def AF(t):
    if t < t_dr:
        return alpha_f
    elif t >= t_dr and t < 2.5*t_dr:
        return alpha_f*(2.5*t_dr - t)/(1.5*t_dr)
    else:
        return 0
        
def update_H(H, P, C, t, D):
    n = len(H)
    h = 1/(n-1)
    alpha = (D_diff*t)/(h**2)
    M = H + (k_off*C)
    M[0] += (alpha_HH/D_diff)*2*h*alpha
    
    Differentiation_Matrix = D
    matrix_HP = np.matmul(k_off*P, np.identity(n))
    matrix_gamma = gamma_H * np.identity(n)
    
    A = np.identity(n) - ((alpha*Differentiation_Matrix) - matrix_HP - matrix_gamma)
    future_H = np.linalg.solve(A, M)
    
    future_H[future_H < 0] = 0
    return future_H

def phi_AR(A,R):
    num = A**2 + K_gli*A
    den = A**2 + 2*K_gli*A + 2*K_gli*R + 2*A*R + R**2 + K_gli**2
    return num/den


def update_P(H, A, P, R, C, t):
    phi = phi_AR(A,R)
    n = len(H)
    delta = ((alpha_ptc)*np.ones(n)) + ((alpha_ptc)*beta*phi) - (gamma_p*P) - (k_on*H*P) + (k_off*C)
    future_P = P + delta*t
    future_P[future_P < 0] = 0
    return future_P
    
def update_C(H, P, C, t):
    n = len(H)
    delta = (k_on*H*P) - (k_off*C) - (gamma_c*C)
    future_C = C + delta*t
    future_C[future_C < 0] = 0      
    return future_C

def update_F2(A,R,P,F2,t, elapsed_time):
    af = AF(elapsed_time)
    phi = phi_AR(A,R)
    g1 = af*(1+beta_fl*phi)
    g2 = alpha_a*((K_p**n_p)/((K_p**n_p)+(P**n_p))) + alpha_R2 + gamma_f
    delta = (g1 - g2*F2)
    future_F2 = F2 + delta*t
    future_F2[future_F2 < 0] = 0
    return future_F2

def update_F3(P,F3,t, elapsed_time):
    af = AF(elapsed_time)
    delta = af - (alpha_a*((K_p**n_p)/((K_p**n_p)+(P**n_p))) + alpha_R3 + gamma_f)*F3
    future_F3 = F3 + delta*t
    future_F3[future_F3 < 0] = 0
    return future_F3   

def update_R(F2, F3, R, t):
    delta = alpha_R2*F2 + alpha_R3*F3 - gamma_R*R
    future_R = R + delta*t
    future_R[future_R < 0] = 0
    return future_R
    
def update_A(P, F2, F3, A, t):
    delta = alpha_a*((K_p**n_p)/((K_p**n_p)+(P**n_p)))*(F2+F3) - gamma_a*A
    future_A = A + delta*t
    future_A[future_A < 0] = 0
    return future_A

def update_S(R, A, S, t):
    gamma_S = 0
    phi = phi_AR(A,R)
    n = len(R)
    delta = (alpha_GBS0*np.ones(n)) + (alpha_GBS*phi) - (gamma_S * S)
    future_S = S + delta*t
    future_S[future_S < 0] = 0
    return future_S, delta

# %%
def integrate_solution(final_time, time_step, n):
    H = np.zeros(n)
    C = np.zeros(n)
    S = np.zeros(n)
    F2 = 125*np.ones(n)
    F3 = 22*np.ones(n)
    A = 6*np.ones(n)
    P = 4*np.ones(n)
    R = 550*np.ones(n)
    time = 0; #start time
    D = create_d_matrix(n); #create differentiation matrix for diffusion
    min_to_collect_at = 30;
    hrs = int( np.floor( final_time / min_to_collect_at)); #number of hours we will simulate over
    
    #make arrays to hold the values of each protein at each grid point at each hour
    H_vals = np.zeros((hrs+1,n));
    H_vals[0] = H; #initialize at t=0
    C_vals = np.zeros((hrs+1,n));
    C_vals[0] = C; #initialize at t=0
    S_vals = []; #need this to be a list since we are appending at every half-min
    S_vals.append(S); #initialize at t=0
    P_vals = np.zeros((hrs+1,n));
    P_vals[0] = P; #initialize at t=0
    R_vals = np.zeros((hrs+1,n));
    R_vals[0] = R; #initialize at t=0
    F2_vals = np.zeros((hrs+1,n));
    F2_vals[0] = F2; #initialize at t=0
    F3_vals = np.zeros((hrs+1,n));
    F3_vals[0] = F3; #initialize at t=0
    A_vals = np.zeros((hrs+1,n));
    A_vals[0] = A; #initialize at t=0
    delta_S_vals = []; #need this to be a list since we are appending at every half-min
    S_vals.append(S); #initialize at t=0
    
    #need plus one because there is some rounding error in the addition for the time step
    steps_each_hr = min_to_collect_at / time_step + 1; 
    print("Number of steps to take each hour: ", steps_each_hr);
    steps_each_half_min = 0.5 / time_step; #should be taking sample of S 
    print("Number of steps to take to reach 0.5min : ", steps_each_half_min);
    steps = 0;
    
    while time<final_time:
        #calculate the updates for each protein
        P_upd = update_P(H, A, P, R, C, time_step);
        C_upd = update_C(H, P, C, time_step);
        F2_upd = update_F2(A,R,P,F2,time_step, time/60);
        F3_upd = update_F3(P,F3,time_step, time/60);
        R_upd = update_R(F2, F3, R, time_step);
        A_upd = update_A(P, F2, F3, A, time_step);
        S_upd, delta_S = update_S(R, A, S, time_step);
        
        P = P_upd.copy();
        C = C_upd.copy();
        
        H_upd = update_H(H, P, C, time_step, D);
        #reassign each protein to new concentrations
        H = H_upd.copy();
        F2 = F2_upd.copy();
        F3 = F3_upd.copy();
        R = R_upd.copy();
        A = A_upd.copy();
        S = S_upd.copy();
        
        time += time_step #increment total time
        steps +=1;
        if steps % steps_each_half_min == 0:
            S_vals.append(S);
            delta_S_vals.append(delta_S)
        if steps == steps_each_hr : #we've reached an hour
            #store protein concentrations at each grid point for this hour
            index = int(time / min_to_collect_at);
            print("Index to insert at:", index, " at time ", time);
            H_vals[index] = H;
            P_vals[index] = P;
            C_vals[index] = C;
            F2_vals[index] = F2;
            F3_vals[index] = F3;
            R_vals[index] = R;
            A_vals[index] = A;
            steps = 0; #reinitialize steps
            
    #add results from last time step to matrices
    H_vals[-1] = H;
    P_vals[-1] = P;
    C_vals[-1] = C;
    F2_vals[-1] = F2;
    F3_vals[-1] = F3;
    R_vals[-1] = R;
    A_vals[-1] = A;
    S_vals.append(S);
        
        
    return H_vals, P_vals, C_vals, R_vals, S_vals, F2_vals, F3_vals, A_vals, delta_S_vals;

# %%
from time import clock

c = clock();
hrs_to_sim = 100;
time_step = 0.5;
H, P, C, R, S, F2, F3, A, delta_S = integrate_solution(hrs_to_sim*60, time_step, 420);
stop = clock();

print("Time: {0} min".format( (stop-c)/60 ) );
# Out:
# Number of steps to take each hour:  61.0
# Number of steps to take to reach 0.5min :  1.0
# Index to insert at: 1  at time  30.5
# Index to insert at: 2  at time  61.0
# Index to insert at: 3  at time  91.5
# Index to insert at: 4  at time  122.0
# Index to insert at: 5  at time  152.5
# Index to insert at: 6  at time  183.0
# Index to insert at: 7  at time  213.5
# Index to insert at: 8  at time  244.0
# Index to insert at: 9  at time  274.5
# Index to insert at: 10  at time  305.0
# Index to insert at: 11  at time  335.5
# Index to insert at: 12  at time  366.0
# Index to insert at: 13  at time  396.5
# Index to insert at: 14  at time  427.0
# Index to insert at: 15  at time  457.5
# Index to insert at: 16  at time  488.0
# Index to insert at: 17  at time  518.5
# Index to insert at: 18  at time  549.0
# Index to insert at: 19  at time  579.5
# Index to insert at: 20  at time  610.0
# Index to insert at: 21  at time  640.5
# Index to insert at: 22  at time  671.0
# Index to insert at: 23  at time  701.5
# Index to insert at: 24  at time  732.0
# Index to insert at: 25  at time  762.5
# Index to insert at: 26  at time  793.0
# Index to insert at: 27  at time  823.5
# Index to insert at: 28  at time  854.0
# Index to insert at: 29  at time  884.5
# Index to insert at: 30  at time  915.0
# Index to insert at: 31  at time  945.5
# Index to insert at: 32  at time  976.0
# Index to insert at: 33  at time  1006.5
# Index to insert at: 34  at time  1037.0
# Index to insert at: 35  at time  1067.5
# Index to insert at: 36  at time  1098.0
# Index to insert at: 37  at time  1128.5
# Index to insert at: 38  at time  1159.0
# Index to insert at: 39  at time  1189.5
# Index to insert at: 40  at time  1220.0
# Index to insert at: 41  at time  1250.5
# Index to insert at: 42  at time  1281.0
# Index to insert at: 43  at time  1311.5
# Index to insert at: 44  at time  1342.0
# Index to insert at: 45  at time  1372.5
# Index to insert at: 46  at time  1403.0
# Index to insert at: 47  at time  1433.5
# Index to insert at: 48  at time  1464.0
# Index to insert at: 49  at time  1494.5
# Index to insert at: 50  at time  1525.0
# Index to insert at: 51  at time  1555.5
# Index to insert at: 52  at time  1586.0
# Index to insert at: 53  at time  1616.5
# Index to insert at: 54  at time  1647.0
# Index to insert at: 55  at time  1677.5
# Index to insert at: 56  at time  1708.0
# Index to insert at: 57  at time  1738.5
# Index to insert at: 58  at time  1769.0
# Index to insert at: 59  at time  1799.5
# Index to insert at: 61  at time  1830.0
# Index to insert at: 62  at time  1860.5
# Index to insert at: 63  at time  1891.0
# Index to insert at: 64  at time  1921.5
# Index to insert at: 65  at time  1952.0
# Index to insert at: 66  at time  1982.5
# Index to insert at: 67  at time  2013.0
# Index to insert at: 68  at time  2043.5
# Index to insert at: 69  at time  2074.0
# Index to insert at: 70  at time  2104.5
# Index to insert at: 71  at time  2135.0
# Index to insert at: 72  at time  2165.5
# Index to insert at: 73  at time  2196.0
# Index to insert at: 74  at time  2226.5
# Index to insert at: 75  at time  2257.0
# Index to insert at: 76  at time  2287.5
# Index to insert at: 77  at time  2318.0
# Index to insert at: 78  at time  2348.5
# Index to insert at: 79  at time  2379.0
# Index to insert at: 80  at time  2409.5
# Index to insert at: 81  at time  2440.0
# Index to insert at: 82  at time  2470.5
# Index to insert at: 83  at time  2501.0
# Index to insert at: 84  at time  2531.5
# Index to insert at: 85  at time  2562.0
# Index to insert at: 86  at time  2592.5
# Index to insert at: 87  at time  2623.0
# Index to insert at: 88  at time  2653.5
# Index to insert at: 89  at time  2684.0
# Index to insert at: 90  at time  2714.5
# Index to insert at: 91  at time  2745.0
# Index to insert at: 92  at time  2775.5
# Index to insert at: 93  at time  2806.0
# Index to insert at: 94  at time  2836.5
# Index to insert at: 95  at time  2867.0
# Index to insert at: 96  at time  2897.5
# Index to insert at: 97  at time  2928.0
# Index to insert at: 98  at time  2958.5
# Index to insert at: 99  at time  2989.0
# Index to insert at: 100  at time  3019.5
# Index to insert at: 101  at time  3050.0
# Index to insert at: 102  at time  3080.5
# Index to insert at: 103  at time  3111.0
# Index to insert at: 104  at time  3141.5
# Index to insert at: 105  at time  3172.0
# Index to insert at: 106  at time  3202.5
# Index to insert at: 107  at time  3233.0
# Index to insert at: 108  at time  3263.5
# Index to insert at: 109  at time  3294.0
# Index to insert at: 110  at time  3324.5
# Index to insert at: 111  at time  3355.0
# Index to insert at: 112  at time  3385.5
# Index to insert at: 113  at time  3416.0
# Index to insert at: 114  at time  3446.5
# Index to insert at: 115  at time  3477.0
# Index to insert at: 116  at time  3507.5
# Index to insert at: 117  at time  3538.0
# Index to insert at: 118  at time  3568.5
# Index to insert at: 119  at time  3599.0
# Index to insert at: 120  at time  3629.5
# Index to insert at: 122  at time  3660.0
# Index to insert at: 123  at time  3690.5
# Index to insert at: 124  at time  3721.0
# Index to insert at: 125  at time  3751.5
# Index to insert at: 126  at time  3782.0
# Index to insert at: 127  at time  3812.5
# Index to insert at: 128  at time  3843.0
# Index to insert at: 129  at time  3873.5
# Index to insert at: 130  at time  3904.0
# Index to insert at: 131  at time  3934.5
# Index to insert at: 132  at time  3965.0
# Index to insert at: 133  at time  3995.5
# Index to insert at: 134  at time  4026.0
# Index to insert at: 135  at time  4056.5
# Index to insert at: 136  at time  4087.0
# Index to insert at: 137  at time  4117.5
# Index to insert at: 138  at time  4148.0
# Index to insert at: 139  at time  4178.5
# Index to insert at: 140  at time  4209.0
# Index to insert at: 141  at time  4239.5
# Index to insert at: 142  at time  4270.0
# Index to insert at: 143  at time  4300.5
# Index to insert at: 144  at time  4331.0
# Index to insert at: 145  at time  4361.5
# Index to insert at: 146  at time  4392.0
# Index to insert at: 147  at time  4422.5
# Index to insert at: 148  at time  4453.0
# Index to insert at: 149  at time  4483.5
# Index to insert at: 150  at time  4514.0
# Index to insert at: 151  at time  4544.5
# Index to insert at: 152  at time  4575.0
# Index to insert at: 153  at time  4605.5
# Index to insert at: 154  at time  4636.0
# Index to insert at: 155  at time  4666.5
# Index to insert at: 156  at time  4697.0
# Index to insert at: 157  at time  4727.5
# Index to insert at: 158  at time  4758.0
# Index to insert at: 159  at time  4788.5
# Index to insert at: 160  at time  4819.0
# Index to insert at: 161  at time  4849.5
# Index to insert at: 162  at time  4880.0
# Index to insert at: 163  at time  4910.5
# Index to insert at: 164  at time  4941.0
# Index to insert at: 165  at time  4971.5
# Index to insert at: 166  at time  5002.0
# Index to insert at: 167  at time  5032.5
# Index to insert at: 168  at time  5063.0
# Index to insert at: 169  at time  5093.5
# Index to insert at: 170  at time  5124.0
# Index to insert at: 171  at time  5154.5
# Index to insert at: 172  at time  5185.0
# Index to insert at: 173  at time  5215.5
# Index to insert at: 174  at time  5246.0
# Index to insert at: 175  at time  5276.5
# Index to insert at: 176  at time  5307.0
# Index to insert at: 177  at time  5337.5
# Index to insert at: 178  at time  5368.0
# Index to insert at: 179  at time  5398.5
# Index to insert at: 180  at time  5429.0
# Index to insert at: 181  at time  5459.5
# Index to insert at: 183  at time  5490.0
# Index to insert at: 184  at time  5520.5
# Index to insert at: 185  at time  5551.0
# Index to insert at: 186  at time  5581.5
# Index to insert at: 187  at time  5612.0
# Index to insert at: 188  at time  5642.5
# Index to insert at: 189  at time  5673.0
# Index to insert at: 190  at time  5703.5
# Index to insert at: 191  at time  5734.0
# Index to insert at: 192  at time  5764.5
# Index to insert at: 193  at time  5795.0
# Index to insert at: 194  at time  5825.5
# Index to insert at: 195  at time  5856.0
# Index to insert at: 196  at time  5886.5
# Index to insert at: 197  at time  5917.0
# Index to insert at: 198  at time  5947.5
# Index to insert at: 199  at time  5978.0
# Time: 3.39585355 min

# %%
def normalize_S(S):
    normed_S = S.copy()
    normed_S = normed_S - np.min(normed_S)
    return normed_S

# %%
fig = plt.figure(figsize=(12,7));
ax = plt.subplot(1,1,1);
fontsize = 16
ax.tick_params(labelsize=fontsize);
ax.set_xlabel('x-position', fontsize=fontsize);
ax.set_ylabel('SHH concentration', fontsize=fontsize);

for i in range(len(H)):
    plt.plot(H[i])

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize= 12); 

plt.show();

fig = plt.figure(figsize=(12,7));
ax = plt.subplot(1,1,1);
fontsize = 16
ax.tick_params(labelsize=fontsize);
ax.set_xlabel('x-position', fontsize=fontsize);
ax.set_ylabel('SHH concentration', fontsize=fontsize);

for i in range(len(P)):
    plt.plot(P[i])

#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize= 12); 

plt.show();
# Out:
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(12,7));
ax = plt.subplot(1,1,1);
fontsize = 16
ax.tick_params(labelsize=fontsize);
ax.set_xlabel('x-position', fontsize=fontsize);
ax.set_ylabel('SHH concentration', fontsize=fontsize);

Ss = []
for i in range(len(S)):
    if i % 500 == 0:
        plt.plot(normalize_S(S[i]))
        #plt.plot(delta_S[i])
plt.show()

# %%
S_A = S[0:6000]
S_B = S[6000:]
delta_S_A = delta_S[0:6000]
delta_S_B = delta_S[6000:]

# %%
len(S_A)
# Out:
# 6000

# %%
prots = [H, P, C, R, S_A, S_B, F2, F3, A, delta_S_A, delta_S_B];
names = ["H", "P", "C", "R", "S_A", "S_B", "F2", "F3", "A", 'delta_S_A', 'delta_S_B'];

for i, p in enumerate(prots):
    print(names[i])
    file_name = "{0}_100hr_sim_final.csv".format(names[i]);
    np.savetxt(file_name, p, delimiter=",");
# Out:
# H
# P
# C
# R
# S_A
# S_B
# F2
# F3
# A
# delta_S_A
# delta_S_B
