# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import math
import scipy.optimize as optimize
from scipy import integrate

# %%
#Define parameters from paper

alpha_ptc = 0.024
gamma_p = 0.006
gamma_c = 0.1539
K_h = 2.2771
k_off = 0.3018
k_on = K_h * k_off
K_p = 0.5660
n_p = 0.9
alpha_R = 0.3908
gamma_R = 0.002
K_R = 8.5184
n_R = 1.5735
alpha_GBS = 5.6881e-3
alpha_GBS0 = 9.8715e-5
D_diff = 58.3931
alpha_HH = 0.5431
gamma_H = 8.1346e-4
beta = 36
m = 1.8657

# %%
def create_d_matrix(n):
    h = 1/(n-1)
    D = -2*np.identity(n)
    
    for i in range(n-1):
        D[i+1, i] = 1
        D[i, i+1] = 1
        
    D[n-1] = 0
    D[0,1] = 2
    
    return D

# %%
def update_H(H, P, C, t):
    n = len(H)
    h = 1/(n-1)
    alpha = (D_diff*t)/(h**2)
    M = H - (gamma_H*H) - (k_on*H*P) + (k_off*C)
    M[0] += (alpha_HH/D_diff)*2*h*alpha
    Differentiation_Matrix = create_d_matrix(n)
    A = np.identity(n) - alpha*Differentiation_Matrix
    future_H = np.linalg.solve(A, M)
    
    
    for i in range(n):
        if future_H[i] < 0:
            future_H[i] = 0
    
    return future_H

def phi_R(R):
    n = len(R)
    phi = np.zeros(n)
    for i in range(n):
        phi[i] = (K_R**n_R)/((K_R**n_R)+(R[i]**n_R))
    return phi

def update_P(H, P, R, C, t):
    n = len(H)
    delta = ((alpha_ptc)*np.ones(n)) + ((alpha_ptc)*beta*phi_R(R)) - (gamma_p*P) - (k_on*H*P) + (k_off*C)
    future_P = P + delta*t
    
    for i in range(n):
        if future_P[i] < 0:
            future_P[i] = 0
    return future_P
    
def update_C(H, P, C, t):
    n = len(H)
    delta = (k_on*H*P) - (k_off*C) - (gamma_c*C)
    future_C = C + delta*t
    
    for i in range(n):
        if future_C[i] < 0:
            future_C[i] = 0
            
    return future_C

def update_R(P, R, t):
    n = len(P)
    delta = np.zeros(n)
    for i in range(n):
        delta[i] = alpha_R*((P[i]**n_p)/((K_p**n_p)+(P[i]**n_p))) - (gamma_R*R[i])
    future_R = R + delta*t
    
    for i in range(n):
        if future_R[i] < 0:
            future_R[i] = 0
            
    return future_R

def update_S(R, S, t):
    n = len(R)
    delta = ((alpha_GBS0*np.ones(n)) + (alpha_GBS*phi_R(R))) #*1000
    future_S = S + delta*t
    
    for i in range(n):
        if future_S[i] < 0:
            future_S[i] = 0
    return future_S

# %%
def integrate_solution(final_time, time_step, n):
    H = np.zeros(n)
    C = np.zeros(n)
    S = np.zeros(n)
    P = 5.25*np.ones(n)
    R = 172.23*np.ones(n) #188.735*np.ones(n)
    time = 0
    Hs = H[0]
    
    while time<final_time:
        H = update_H(H, P, C, time_step)
        P = update_P(H, P, R, C, time_step)
        C = update_C(H, P, C, time_step)
        R = update_R(P, R, time_step)
        S = update_S(R, S, time_step)
        
        
        
        time += time_step
        
    return H, P, C, R, S

# %%
H, P, C, R, S = integrate_solution(3000, 1, 1000)

#        171.07072104, 171.07686588, 171.08301149, 171.08915787,
#        171.09530502, 171.10145293, 171.10760162, 171.11375108,
#        171.11990132, 171.12605232, 171.1322041 , 171.13835664,
#        171.14450996, 171.15066406, 171.15681892, 171.16297456,
#        171.16913098, 171.17528816, 171.18144613, 171.18760486,
#        171.19376438, 171.19992466, 171.20608573, 171.21224757,
#        171.21841018, 171.22457358, 171.23073775, 171.2369027 ,
#        171.24306842, 171.24923493, 171.25540221, 171.26157027,
#        171.26773911, 171.27390873, 171.28007913, 171.28625031,
#        171.29242227, 171.29859501, 171.30476853, 171.31094283,
#        171.31711792, 171.32329378, 171.32947043, 171.33564786,
#        171.34182608, 171.34800508, 171.35418486, 171.36036543,
#        171.36654678, 171.37272891, 171.37891183, 171.38509554,
#        171.39128003, 171.39746531, 171.40365137, 171.40983822,
#        171.41602586, 171.42221429, 171.4284035 , 171.4345935 ,
#        171.44078429, 171.44697587, 171.45316824, 171.45936139,
#        171.46555534, 171.47175008, 171.4779456 , 171.48414192,
#        171.49033903, 171.49653693, 171.50273562, 171.50893511,
#        171.51513538, 171.52133645, 171.52753832, 171.53374097,
#        171.53994442, 171.54614867, 171.55235371, 171.55855954,
#        171.56476617, 171.57097359, 171.57718181, 171.58339083,
#        171.58960064, 171.59581125, 171.60202266, 171.60823486,
#        171.61444787, 171.62066167, 171.62687627, 171.63309166,
#        171.63930786, 171.64552486, 171.65174266, 171.65796126,
#        171.66418065, 171.67040085, 171.67662185, 171.68284366,
#        171.68906626, 171.69528967, 171.70151388, 171.70773889,
#        171.71396471, 171.72019133, 171.72641875, 171.73264698,
#        171.73887601, 171.74510585, 171.7513365 , 171.75756795,
#        171.7638002 , 171.77003327, 171.77626714, 171.78250181,
#        171.7887373 , 171.79497359, 171.80121069, 171.8074486 ,
#        171.81368732, 171.81992685, 171.82616719, 171.83240834,
#        171.8386503 , 171.84489307, 171.85113665, 171.85738104,
#        171.86362624, 171.86987226, 171.87611909, 171.88236673,
#        171.88861518, 171.89486445, 171.90111454, 171.90736543,
#        171.91361715, 171.91986967, 171.92612301, 171.93237717,
#        171.93863215, 171.94488794, 171.95114454, 171.95740197,
#        171.96366021, 171.96991927, 171.97617915, 171.98243985,
#        171.98870136, 171.9949637 , 172.00122685, 172.00749083,
#        172.01375563, 172.02002124, 172.02628768, 172.03255494,
#        172.03882302, 172.04509192, 172.05136165, 172.0576322 ,
#        172.06390357, 172.07017577, 172.07644879, 172.08272263,
#        172.0889973 , 172.0952728 , 172.10154911, 172.10782626,
#        172.11410423, 172.12038303, 172.12666266, 172.13294311,
#        172.13922439, 172.1455065 , 172.15178944, 172.1580732 ,
#        172.1643578 , 172.17064322, 172.17692948, 172.18321656,
#        172.18950448, 172.19579322, 172.2020828 , 172.20837321,
#        172.21466445, 172.22095653, 172.22724943, 172.23354317])

# %%
fig, ax = plt.subplots(figsize=(15, 7))
ax.grid(True, lw=1.76, ls='--', alpha = 0.15)
plt.plot(S, '', color = 'b', ms =10)
#plt.plot(R, '', color = 'r', ms =10)
plt.show()
